# %% [markdown]
# # Enhanced Transfer Learning CNN - EfficientNetB0
#
# ## Major Improvements:
# - **Enhanced synthetic data generation** with color variations (not just black on white)
# - **Targeted class balancing** for specific underrepresented classes
# - **Improved architecture** with better regularization
# - **Optimized hyperparameters** (LR, batch size, image size)
# - **Advanced augmentation** with color jitter and more variations
# - **Better focal loss** configuration for quality classes

# %%
import tensorflow as tf
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
)
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.preprocessing import image
from sklearn.model_selection import train_test_split
from tensorflow.keras import backend as K
import cv2
from pathlib import Path

import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
# GPU configuration
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
    print(f"GPU {gpu.name} configured")
# Out:
# GPU /physical_device:GPU:0 configured

# %% [markdown]
# ## Enhanced Synthetic Data Generation with Color Variations

# %%
class EnhancedSketchDatasetBuilder:
    """Enhanced synthetic data generator with color variations and better quality simulation"""
    
    def __init__(self, image_size=128):  # Increased from 224 for better detail
        self.image_size = image_size
        
        self.bg_colors = [
            (255, 255, 255),  # Pure white
            (250, 250, 250),  # Very light gray
            (245, 245, 245),  # Light gray
            ]

        self.fg_colors = [
            (0, 0, 0),        # Pure black
            (15, 15, 15),     # Very dark gray
            (30, 30, 30),     # Dark gray
            ]
    
    def _get_random_colors(self):
        """Get random but visually distinct background and foreground colors"""
        bg = self.bg_colors[np.random.randint(len(self.bg_colors))]
        fg = self.fg_colors[np.random.randint(len(self.fg_colors))]
        
        # Add slight random variation
        bg = tuple(int(x) for x in np.clip(np.array(bg) + np.random.randint(-5, 6, 3), 0, 255))
        fg = tuple(int(x) for x in np.clip(np.array(fg) + np.random.randint(-10, 11, 3), 0, 255))
        
        return bg, fg
    
    def _perturb_vertices(self, vertices, quality_level):
        """Add geometric distortion based on quality level"""
        vertices = np.asarray(vertices, dtype=np.float32)
        
        if quality_level == "Perfect":
            # Minimal perturbation for perfect shapes
            max_offset = int(self.image_size * 0.01)
            distorted = vertices + np.random.uniform(-max_offset, max_offset, vertices.shape)
            return distorted.astype(np.int32)
        
        if quality_level == "Medium":
            jitter_scale = 0.05
        else:  # Irregular
            jitter_scale = 0.15
        
        max_offset = int(self.image_size * jitter_scale)
        
        distorted = []
        for x, y in vertices:
            dx = np.random.randint(-max_offset, max_offset + 1)
            dy = np.random.randint(-max_offset, max_offset + 1)
            distorted.append((x + dx, y + dy))
            
            # Add extra vertices for irregular shapes
            if quality_level == "Irregular" and np.random.rand() < 0.4:
                distorted.append((
                    x + dx + np.random.randint(-max_offset, max_offset),
                    y + dy + np.random.randint(-max_offset, max_offset)
                ))
        
        return np.array(distorted, dtype=np.int32)
    
    def _degrade_raster(self, image, quality_level):
        """Apply post-processing effects based on quality"""
        image = image.copy()
        
        if quality_level == "Perfect":
            # Minimal degradation
            image = cv2.GaussianBlur(image, (3, 3), 0.3)
            noise = np.random.normal(0, 2, image.shape)
            return np.clip(image + noise, 0, 255).astype(np.uint8)
        
        if quality_level == "Medium":
            # Moderate degradation
            image = cv2.GaussianBlur(image, (3, 3), 0.8)
            noise = np.random.normal(0, 10, image.shape)
            image = np.clip(image + noise, 0, 255).astype(np.uint8)
            
            # Random morphological operations
            kernel_size = np.random.choice([3, 5])
            kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
            if np.random.rand() < 0.5:
                image = cv2.dilate(image, kernel, iterations=1)
            else:
                image = cv2.erode(image, kernel, iterations=1)
            
            return image
        
        # Irregular - heavy degradation
        image = cv2.GaussianBlur(image, (5, 5), 1.5)
        noise = np.random.normal(0, 20, image.shape)
        image = np.clip(image + noise, 0, 255).astype(np.uint8)
        
        # Multiple morphological operations
        kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3, 3))
        for _ in range(np.random.randint(1, 4)):
            if np.random.rand() < 0.5:
                image = cv2.dilate(image, kernel, iterations=1)
            else:
                image = cv2.erode(image, kernel, iterations=1)
        
        # Add some random scratches/artifacts
        if np.random.rand() < 0.3:
            num_scratches = np.random.randint(2, 6)
            for _ in range(num_scratches):
                pt1 = (np.random.randint(0, self.image_size), np.random.randint(0, self.image_size))
                pt2 = (np.random.randint(0, self.image_size), np.random.randint(0, self.image_size))
                cv2.line(image, pt1, pt2, 
                        tuple(np.random.randint(0, 50, 3).tolist()), 
                        np.random.randint(1, 3))
        
        return image
    
    def _empty_canvas(self, bg_color):
        """Create canvas with specified background color"""
        return np.full(
            (self.image_size, self.image_size, 3),
            bg_color,
            dtype=np.uint8
        )
    
    def _draw_triangle(self, quality_level, bg_color, fg_color):
        """Draw triangle with quality variations"""
        img = self._empty_canvas(bg_color)
        c = self.image_size // 2
        scale = np.random.uniform(0.55, 0.85)
        
        # Define triangle vertices
        vertices = [
            (c, c - int(c * 0.75 * scale)),  # Top
            (c - int(c * 0.65 * scale), c + int(c * 0.65 * scale)),  # Bottom-left
            (c + int(c * 0.65 * scale), c + int(c * 0.65 * scale)),  # Bottom-right
        ]
        
        contour = self._perturb_vertices(vertices, quality_level)
        
        # Variable line thickness
        thickness = np.random.randint(2, 4) if quality_level != "Irregular" else np.random.randint(2, 5)
        cv2.drawContours(img, [contour], -1, fg_color, thickness)
        
        return self._degrade_raster(img, quality_level)
    
    def _draw_square(self, quality_level, bg_color, fg_color):
        """Draw square with quality variations"""
        img = self._empty_canvas(bg_color)
        c = self.image_size // 2
        half = int(c * np.random.uniform(0.5, 0.7))
        
        vertices = [
            (c - half, c - half),  # Top-left
            (c + half, c - half),  # Top-right
            (c + half, c + half),  # Bottom-right
            (c - half, c + half),  # Bottom-left
        ]
        
        contour = self._perturb_vertices(vertices, quality_level)
        
        thickness = np.random.randint(2, 4) if quality_level != "Irregular" else np.random.randint(2, 5)
        cv2.drawContours(img, [contour], -1, fg_color, thickness)
        
        return self._degrade_raster(img, quality_level)
    
    def _draw_circle(self, quality_level, bg_color, fg_color):
        """Draw circle with quality variations"""
        img = self._empty_canvas(bg_color)
        c = self.image_size // 2
        r = int(c * np.random.uniform(0.55, 0.75))
        
        thickness = np.random.randint(2, 4) if quality_level != "Irregular" else np.random.randint(2, 5)
        
        if quality_level == "Perfect":
            # Perfect circle
            cv2.circle(img, (c, c), r, fg_color, thickness)
        else:
            # Ellipse with varying axis ratios
            if quality_level == "Medium":
                axis_jitter = 0.15
            else:  # Irregular
                axis_jitter = 0.35
            
            rx = int(r * (1 + np.random.uniform(-axis_jitter, axis_jitter)))
            ry = int(r * (1 + np.random.uniform(-axis_jitter, axis_jitter)))
            angle = np.random.uniform(0, 360)
            
            cv2.ellipse(img, (c, c), (abs(rx), abs(ry)), angle, 0, 360, fg_color, thickness)
        
        return self._degrade_raster(img, quality_level)
    
    def render_sample(self, shape_name, quality_level):
        """Generate a synthetic sample with color variations"""
        bg_color, fg_color = self._get_random_colors()
        
        dispatch = {
            "Triangle": self._draw_triangle,
            "Square": self._draw_square,
            "Circle": self._draw_circle,
        }
        
        return dispatch[shape_name](quality_level, bg_color, fg_color)
    
    def visualize_samples(self, num_samples=9):
        """Visualize generated samples"""
        fig, axes = plt.subplots(3, 3, figsize=(12, 12))
        shapes = ["Circle", "Square", "Triangle"]
        qualities = ["Perfect", "Medium", "Irregular"]
        
        for i, shape in enumerate(shapes):
            for j, quality in enumerate(qualities):
                img = self.render_sample(shape, quality)
                axes[i, j].imshow(img)
                axes[i, j].set_title(f"{shape} - {quality}", fontweight='bold')
                axes[i, j].axis('off')
        
        plt.tight_layout()
        plt.show()

# %%
# Visualize synthetic data samples
print("Visualizing enhanced synthetic data generation...")
builder = EnhancedSketchDatasetBuilder(image_size=256)
builder.visualize_samples()
# Out:
# Visualizing enhanced synthetic data generation...

# %% [markdown]
# ## Load Real Dataset

# %%
data_dir = '/kaggle/input/fai-dataset/Dataset_FAI'

def create_dual_label_dataframe(data_dir):
    file_paths = []
    shapes = []
    qualities = []
    
    for shape in os.listdir(data_dir):
        shape_path = os.path.join(data_dir, shape)
        if not os.path.isdir(shape_path):
            continue
            
        for quality in os.listdir(shape_path):
            quality_path = os.path.join(shape_path, quality)
            if not os.path.isdir(quality_path):
                continue
                
            for img_file in os.listdir(quality_path):
                if img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
                    file_paths.append(os.path.join(quality_path, img_file))
                    
                    # Normalize shape names
                    if shape == 'Triangles':
                        shapes.append('Triangle')
                    elif shape == 'Squares':
                        shapes.append('Square')
                    else:
                        shapes.append(shape)
                    
                    # Fix typo in quality
                    if quality == 'Iregullar':
                        qualities.append('Irregular')
                    else:
                        qualities.append(quality)
    
    df = pd.DataFrame({
        'filepath': file_paths,
        'shape': shapes,
        'quality': qualities
    })
    
    return df

df = create_dual_label_dataframe(data_dir)
print(f"Total real images: {len(df)}")
print(f"\nShape distribution:\n{df['shape'].value_counts()}")
print(f"\nQuality distribution:\n{df['quality'].value_counts()}")

# Detailed breakdown
print("\n" + "="*60)
print("Detailed Class Distribution:")
print("="*60)
for shape in ['Circle', 'Square', 'Triangle']:
    shape_df = df[df['shape'] == shape]
    print(f"\n{shape} ({len(shape_df)} total):")
    for quality in ['Irregular', 'Medium', 'Perfect']:
        count = len(shape_df[shape_df['quality'] == quality])
        print(f"  {quality}: {count}")
# Out:
# Total real images: 1575
#
# Shape distribution:
# shape
# Square      542
# Circle      532
# Triangle    501
# Name: count, dtype: int64
#
# Quality distribution:
# quality
# Irregular    639
# Medium       614
# Perfect      322
# Name: count, dtype: int64
#
# ============================================================
# Detailed Class Distribution:
# ============================================================
#
# Circle (532 total):
#   Irregular: 198
#   Medium: 242
#   Perfect: 92
#
# Square (542 total):
#   Irregular: 272
#   Medium: 161
#   Perfect: 109
#
# Triangle (501 total):
#   Irregular: 169
#   Medium: 211
#   Perfect: 121

# %%
import random
print("\nVisualizing random samples from REAL dataset:")
fig, axes = plt.subplots(3, 3, figsize=(12, 12))
for i in range(9):
    idx = random.randint(0, len(train_df)-1)
    img_path = train_df.iloc[idx]['filepath']
    img = cv2.imread(img_path)
    axes[i//3, i%3].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    axes[i//3, i%3].set_title(f"{train_df.iloc[idx]['shape']} - {train_df.iloc[idx]['quality']}")
    axes[i//3, i%3].axis('off')
plt.tight_layout()
plt.show()
# Out:
# Visualizing random samples from REAL dataset:

# %%
shape_classes = ['Circle', 'Square', 'Triangle']
quality_classes = ['Irregular', 'Medium', 'Perfect']

# %%
# Split data with stratification
df['combined_label'] = df['shape'] + '_' + df['quality']

train_df, temp_df = train_test_split(
    df, test_size=0.2, random_state=42, stratify=df['combined_label']
)
val_df, test_df = train_test_split(
    temp_df, test_size=0.5, random_state=42, stratify=temp_df['combined_label']
)

print(f"Training: {len(train_df)}, Validation: {len(val_df)}, Test: {len(test_df)}")
# Out:
# Training: 1260, Validation: 157, Test: 158

# %% [markdown]
# ## Generate Targeted Synthetic Data for Specific Underrepresented Classes

# %%
print("Generating TARGETED synthetic samples for underrepresented classes...")
print("="*70)

synthetic_data = []
builder = EnhancedSketchDatasetBuilder(image_size=128)

# Define targeted augmentation strategy
# Based on your requirements:
# - Perfect shapes: Generate ~150 for each (they're severely underrepresented)
# - Medium Square: Add 60-65 to reach ~225
# - Irregular Triangle: Add 50-56 to reach ~225

synthetic_targets = {
    ('Circle', 'Perfect'): 80,
    ('Square', 'Perfect'): 80,
    ('Triangle', 'Perfect'): 80,
    ('Square', 'Medium'): 40,
    ('Triangle', 'Irregular'): 35,
}

for (shape, quality), num_synthetic in synthetic_targets.items():
    print(f"\nGenerating {num_synthetic} synthetic {shape} - {quality} samples...")
    
    for i in range(num_synthetic):
        img = builder.render_sample(shape, quality)
        
        # Save temporary file
        temp_path = f"/tmp/synthetic_{shape}_{quality}_{len(synthetic_data):04d}.png"
        cv2.imwrite(temp_path, cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
        
        synthetic_data.append({
            'filepath': temp_path,
            'shape': shape,
            'quality': quality,
            'combined_label': f"{shape}_{quality}"
        })
        
        if (i + 1) % 50 == 0:
            print(f"  Generated {i + 1}/{num_synthetic}...")

# Add synthetic data to training set
synthetic_df = pd.DataFrame(synthetic_data)
original_train_len = len(train_df)
train_df = pd.concat([train_df, synthetic_df], ignore_index=True)

print("\n" + "="*70)
print(f"Original training set: {original_train_len} samples")
print(f"Synthetic samples added: {len(synthetic_df)} samples")
print(f"Augmented training set: {len(train_df)} samples")
print("="*70)

# Show new distribution
print("\nNew Quality Distribution:")
print(train_df['quality'].value_counts())

print("\nDetailed Augmented Class Distribution:")
print("="*60)
for shape in shape_classes:
    shape_df = train_df[train_df['shape'] == shape]
    print(f"\n{shape} ({len(shape_df)} total):")
    for quality in quality_classes:
        count = len(shape_df[shape_df['quality'] == quality])
        print(f"  {quality}: {count}")
# Out:
# Generating TARGETED synthetic samples for underrepresented classes...
# ======================================================================
#
# Generating 80 synthetic Circle - Perfect samples...
#   Generated 50/80...
#
# Generating 80 synthetic Square - Perfect samples...
#   Generated 50/80...
#
# Generating 80 synthetic Triangle - Perfect samples...
#   Generated 50/80...
#
# Generating 40 synthetic Square - Medium samples...
#
# Generating 35 synthetic Triangle - Irregular samples...
#
# ======================================================================
# Original training set: 1260 samples
# Synthetic samples added: 315 samples
# Augmented training set: 1575 samples
# ======================================================================
#
# New Quality Distribution:
# quality
# Irregular    546
# Medium       531
# Perfect      498
# Name: count, dtype: int64
#
# Detailed Augmented Class Distribution:
# ============================================================
#
# Circle (505 total):
#   Irregular: 158
#   Medium: 193
#   Perfect: 154
#
# Square (554 total):
#   Irregular: 218
#   Medium: 169
#   Perfect: 167
#
# Triangle (516 total):
#   Irregular: 170
#   Medium: 169
#   Perfect: 177

# %%
# Compute class weights (they'll be more balanced now)
shape_labels = [shape_classes.index(s) for s in train_df['shape']]
shape_class_weights = compute_class_weight(
    'balanced', classes=np.unique(shape_labels), y=shape_labels
)
shape_class_weight_dict = dict(enumerate(shape_class_weights))

quality_labels = [quality_classes.index(q) for q in train_df['quality']]
quality_class_weights = compute_class_weight(
    'balanced', classes=np.unique(quality_labels), y=quality_labels
)
quality_class_weight_dict = dict(enumerate(quality_class_weights))

print(f"Shape weights: {shape_class_weight_dict}")
print(f"Quality weights: {quality_class_weight_dict}")
# Out:
# Shape weights: {0: np.float64(1.0396039603960396), 1: np.float64(0.9476534296028881), 2: np.float64(1.0174418604651163)}
# Quality weights: {0: np.float64(0.9615384615384616), 1: np.float64(0.9887005649717514), 2: np.float64(1.0542168674698795)}

# %% [markdown]
# ## Enhanced Data Augmentation

# %%
# More aggressive augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=45,  # Increased from 40
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=0.25,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.6, 1.4],  # More variation
    fill_mode='nearest'
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

print("Data augmentation configured with enhanced parameters")
# Out:
# Data augmentation configured with enhanced parameters

# %%
def dual_label_generator(dataframe, datagen, batch_size, img_size, shuffle=True):
    """Generate batches of images with dual labels (shape and quality)"""
    while True:
        if shuffle:
            dataframe = dataframe.sample(frac=1).reset_index(drop=True)
        
        for start in range(0, len(dataframe), batch_size):
            end = min(start + batch_size, len(dataframe))
            batch_df = dataframe.iloc[start:end]
            
            batch_images = []
            batch_shape_labels = []
            batch_quality_labels = []
            
            for _, row in batch_df.iterrows():
                img = image.load_img(row['filepath'], target_size=img_size)
                img_array = image.img_to_array(img)
                img_array = datagen.random_transform(img_array)
                img_array = datagen.standardize(img_array)
                
                batch_images.append(img_array)
                
                shape_label = np.zeros(len(shape_classes))
                shape_label[shape_classes.index(row['shape'])] = 1
                batch_shape_labels.append(shape_label)
                
                quality_label = np.zeros(len(quality_classes))
                quality_label[quality_classes.index(row['quality'])] = 1
                batch_quality_labels.append(quality_label)
            
            X = np.array(batch_images)
            y = {
                'shape_output': np.array(batch_shape_labels),
                'quality_output': np.array(batch_quality_labels)
            }
            
            yield X, y

# %% [markdown]
# ## Improved Loss Functions

# %%
def focal_loss(gamma=2.0, alpha=0.25):
    """Focal loss for handling class imbalance"""
    def focal_loss_fixed(y_true, y_pred):
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        cross_entropy = -y_true * K.log(y_pred)
        loss = alpha * K.pow(1 - y_pred, gamma) * cross_entropy
        return K.mean(K.sum(loss, axis=-1))
    
    return focal_loss_fixed

def weighted_categorical_crossentropy(class_weights):
    """Weighted categorical crossentropy for imbalanced classes"""
    class_weights_tensor = tf.constant(list(class_weights.values()), dtype=tf.float32)
    
    def loss(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        crossentropy = -tf.reduce_sum(y_true * tf.math.log(y_pred), axis=-1)
        class_indices = tf.argmax(y_true, axis=-1)
        weights = tf.gather(class_weights_tensor, class_indices)
        return tf.reduce_mean(crossentropy * weights)
    
    return loss

# Configure loss functions with better parameters
shape_loss_fn = weighted_categorical_crossentropy(shape_class_weight_dict)
quality_loss_fn = focal_loss(gamma=4.0, alpha=0.4)

print("Loss functions configured")
# Out:
# Loss functions configured

# %% [markdown]
# ## Enhanced Transfer Learning Model

# %%
def create_enhanced_transfer_learning_model(input_shape=(128, 128, 3), unfreeze_from=80):
    # Load EfficientNetB0 with 256x256 input
    base_model = EfficientNetB0(
        weights='imagenet',
        include_top=False,
        input_shape=input_shape
    )
    
    # Unfreeze more layers for better fine-tuning
    base_model.trainable = True
    for layer in base_model.layers[:unfreeze_from]:
        layer.trainable = False
    
    trainable_count = sum([1 for layer in base_model.layers if layer.trainable])
    print(f"Total layers: {len(base_model.layers)}")
    print(f"Trainable layers: {trainable_count}")
    print(f"Frozen layers: {len(base_model.layers) - trainable_count}")
    
    # Build enhanced model
    inputs = Input(shape=input_shape)
    x = base_model(inputs, training=True)
    x = GlobalAveragePooling2D()(x)
    
    # Shared feature layers with better regularization
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)
    
    # Shape branch (simpler since shape classification is easier)
    shape_branch = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
    shape_branch = Dropout(0.3)(shape_branch)
    shape_output = Dense(len(shape_classes), activation='softmax', name='shape_output')(shape_branch)
    
    # Quality branch (deeper because quality classification is harder)
    quality_branch = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
    quality_branch = BatchNormalization()(quality_branch)
    quality_branch = Dropout(0.45)(quality_branch)
    
    quality_branch = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(quality_branch)
    quality_branch = BatchNormalization()(quality_branch)
    quality_branch = Dropout(0.4)(quality_branch)
    
    quality_branch = Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(quality_branch)
    quality_branch = Dropout(0.3)(quality_branch)
    
    quality_output = Dense(len(quality_classes), activation='softmax', name='quality_output')(quality_branch)
    
    model = Model(inputs=inputs, outputs=[shape_output, quality_output])
    return model

print("Creating enhanced model...")
model = create_enhanced_transfer_learning_model()
print(f"\nTotal parameters: {model.count_params():,}")

trainable_params = sum([K.count_params(w) for w in model.trainable_weights])
non_trainable_params = sum([K.count_params(w) for w in model.non_trainable_weights])
print(f"Trainable parameters: {trainable_params:,}")
print(f"Non-trainable parameters: {non_trainable_params:,}")
# Out:
# Creating enhanced model...
# Total layers: 238
# Trainable layers: 158
# Frozen layers: 80
#
# Total parameters: 4,981,801
# Trainable parameters: 4,861,664
# Non-trainable parameters: 120,137.0

# %% [markdown]
# ## Improved Training Configuration

# %%
# Enhanced hyperparameters
img_size = (128, 128)  # Increased from 224x224
batch_size = 32  # Reduced from 32 for better gradient estimates with larger images
epochs = 50  # Increased from 60
initial_learning_rate = 0.001  # Slightly higher initial LR

# Calculate steps
train_steps = len(train_df) // batch_size
val_steps = len(val_df) // batch_size
test_steps = len(test_df) // batch_size

print("="*70)
print("Training Configuration:")
print("="*70)
print(f"Image size: {img_size}")
print(f"Batch size: {batch_size}")
print(f"Epochs: {epochs}")
print(f"Initial learning rate: {initial_learning_rate}")
print(f"\nSteps per epoch:")
print(f"  Train: {train_steps}")
print(f"  Validation: {val_steps}")
print(f"  Test: {test_steps}")
print("="*70)
# Out:
# ======================================================================
# Training Configuration:
# ======================================================================
# Image size: (128, 128)
# Batch size: 32
# Epochs: 50
# Initial learning rate: 0.001
#
# Steps per epoch:
#   Train: 49
#   Validation: 4
#   Test: 4
# ======================================================================

# %%
# Create generators
train_generator = dual_label_generator(train_df, train_datagen, batch_size, img_size, shuffle=True)
val_generator = dual_label_generator(val_df, val_test_datagen, batch_size, img_size, shuffle=False)
test_generator = dual_label_generator(test_df, val_test_datagen, batch_size, img_size, shuffle=False)

print("Data generators created")
# Out:
# Data generators created

# %%
# Compile with cosine decay learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate,
    decay_steps=train_steps * epochs,
    alpha=0.01  # Minimum LR will be 1% of initial
)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(
    optimizer=optimizer,
    loss={
        'shape_output': shape_loss_fn,
        'quality_output': quality_loss_fn
    },
    loss_weights={
    'shape_output': 0.5,
    'quality_output': 2.5
    },
    metrics={
        'shape_output': ['accuracy'],
        'quality_output': ['accuracy']
    }
)

print("Model compiled with cosine decay learning rate schedule")
# Out:
# Model compiled with cosine decay learning rate schedule

# %%
# Enhanced callbacks
from tensorflow.keras.callbacks import (
    ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard
)
import datetime

# Create log directory for TensorBoard
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

callbacks = [
    ModelCheckpoint(
        'enhanced_transfer_learning_best.h5',
        monitor='val_quality_output_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    ),
    EarlyStopping(
        monitor='val_quality_output_accuracy',
        patience=25,  # Increased patience
        mode='max',
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,  # Slightly increased
        min_lr=1e-7,
        verbose=1
    ),
    TensorBoard(
        log_dir=log_dir,
        histogram_freq=1,
        write_graph=True
    )
]

print("Callbacks configured")
print(f"TensorBoard logs: {log_dir}")
# Out:
# Callbacks configured
# TensorBoard logs: logs/fit/20260112-165646

# %% [markdown]
# ## Train Enhanced Model

# %%
print("\n" + "="*70)
print("Starting training...")
print("="*70 + "\n")

history = model.fit(
    train_generator,
    steps_per_epoch=train_steps,
    epochs=epochs,
    validation_data=val_generator,
    validation_steps=val_steps,
    callbacks=callbacks,
    verbose=1
)

print("\n" + "="*70)
print("Training completed!")
print("="*70)
# Out:
# ======================================================================
# Starting training...
# ======================================================================
#
# Epoch 1/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - loss: 3.6274 - quality_output_accuracy: 0.3578 - quality_output_loss: 0.4186 - shape_output_accuracy: 0.4008 - shape_output_loss: 1.6326
# Epoch 1: val_quality_output_accuracy improved from -inf to 0.19531, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 105s 731ms/step - loss: 3.6236 - quality_output_accuracy: 0.3580 - quality_output_loss: 0.4175 - shape_output_accuracy: 0.4009 - shape_output_loss: 1.6303 - val_loss: 2.5688 - val_quality_output_accuracy: 0.1953 - val_quality_output_loss: 0.0959 - val_shape_output_accuracy: 0.2812 - val_shape_output_loss: 1.0970 - learning_rate: 9.9902e-04
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - loss: 3.2383 - quality_output_accuracy: 0.3315 - quality_output_loss: 0.3113 - shape_output_accuracy: 0.4344 - shape_output_loss: 1.3523
# Epoch 2: val_quality_output_accuracy improved from 0.19531 to 0.43750, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 56s 550ms/step - loss: 3.2373 - quality_output_accuracy: 0.3312 - quality_output_loss: 0.3111 - shape_output_accuracy: 0.4344 - shape_output_loss: 1.3513 - val_loss: 2.6204 - val_quality_output_accuracy: 0.4375 - val_quality_output_loss: 0.1132 - val_shape_output_accuracy: 0.2656 - val_shape_output_loss: 1.1126 - learning_rate: 9.9610e-04
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - loss: 2.9318 - quality_output_accuracy: 0.3454 - quality_output_loss: 0.2296 - shape_output_accuracy: 0.4865 - shape_output_loss: 1.1660
# Epoch 3: val_quality_output_accuracy improved from 0.43750 to 0.45312, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 27s 559ms/step - loss: 2.9314 - quality_output_accuracy: 0.3453 - quality_output_loss: 0.2297 - shape_output_accuracy: 0.4867 - shape_output_loss: 1.1649 - val_loss: 2.5019 - val_quality_output_accuracy: 0.4531 - val_quality_output_loss: 0.0927 - val_shape_output_accuracy: 0.4688 - val_shape_output_loss: 0.9995 - learning_rate: 9.9123e-04
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - loss: 2.8281 - quality_output_accuracy: 0.3582 - quality_output_loss: 0.1944 - shape_output_accuracy: 0.4805 - shape_output_loss: 1.1595
# Epoch 4: val_quality_output_accuracy improved from 0.45312 to 0.45600, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 30s 618ms/step - loss: 2.8276 - quality_output_accuracy: 0.3581 - quality_output_loss: 0.1944 - shape_output_accuracy: 0.4806 - shape_output_loss: 1.1585 - val_loss: 2.3913 - val_quality_output_accuracy: 0.4560 - val_quality_output_loss: 0.0849 - val_shape_output_accuracy: 0.5600 - val_shape_output_loss: 0.8464 - learning_rate: 9.8445e-04
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - loss: 2.6685 - quality_output_accuracy: 0.3453 - quality_output_loss: 0.1669 - shape_output_accuracy: 0.5295 - shape_output_loss: 0.9843
# Epoch 5: val_quality_output_accuracy improved from 0.45600 to 0.47200, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 440ms/step - loss: 2.6679 - quality_output_accuracy: 0.3452 - quality_output_loss: 0.1669 - shape_output_accuracy: 0.5300 - shape_output_loss: 0.9838 - val_loss: 2.3503 - val_quality_output_accuracy: 0.4720 - val_quality_output_loss: 0.0954 - val_shape_output_accuracy: 0.6160 - val_shape_output_loss: 0.7582 - learning_rate: 9.7577e-04
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - loss: 2.5257 - quality_output_accuracy: 0.3759 - quality_output_loss: 0.1478 - shape_output_accuracy: 0.5689 - shape_output_loss: 0.8540
# Epoch 6: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 474ms/step - loss: 2.5253 - quality_output_accuracy: 0.3757 - quality_output_loss: 0.1478 - shape_output_accuracy: 0.5692 - shape_output_loss: 0.8535 - val_loss: 2.2774 - val_quality_output_accuracy: 0.4219 - val_quality_output_loss: 0.0848 - val_shape_output_accuracy: 0.6406 - val_shape_output_loss: 0.7089 - learning_rate: 9.6524e-04
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - loss: 2.4747 - quality_output_accuracy: 0.3483 - quality_output_loss: 0.1400 - shape_output_accuracy: 0.5888 - shape_output_loss: 0.8548
# Epoch 7: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 494ms/step - loss: 2.4742 - quality_output_accuracy: 0.3486 - quality_output_loss: 0.1398 - shape_output_accuracy: 0.5889 - shape_output_loss: 0.8546 - val_loss: 2.2205 - val_quality_output_accuracy: 0.3516 - val_quality_output_loss: 0.0860 - val_shape_output_accuracy: 0.6328 - val_shape_output_loss: 0.6419 - learning_rate: 9.5289e-04
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - loss: 2.3946 - quality_output_accuracy: 0.3712 - quality_output_loss: 0.1274 - shape_output_accuracy: 0.6019 - shape_output_loss: 0.8001
# Epoch 8: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 480ms/step - loss: 2.3943 - quality_output_accuracy: 0.3711 - quality_output_loss: 0.1274 - shape_output_accuracy: 0.6020 - shape_output_loss: 0.7999 - val_loss: 2.1978 - val_quality_output_accuracy: 0.4219 - val_quality_output_loss: 0.0946 - val_shape_output_accuracy: 0.6875 - val_shape_output_loss: 0.6094 - learning_rate: 9.3877e-04
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - loss: 2.2979 - quality_output_accuracy: 0.4037 - quality_output_loss: 0.1135 - shape_output_accuracy: 0.6260 - shape_output_loss: 0.7539
# Epoch 9: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 487ms/step - loss: 2.2979 - quality_output_accuracy: 0.4034 - quality_output_loss: 0.1135 - shape_output_accuracy: 0.6262 - shape_output_loss: 0.7536 - val_loss: 2.1030 - val_quality_output_accuracy: 0.3920 - val_quality_output_loss: 0.0832 - val_shape_output_accuracy: 0.7280 - val_shape_output_loss: 0.5278 - learning_rate: 9.2294e-04
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - loss: 2.2510 - quality_output_accuracy: 0.3389 - quality_output_loss: 0.1138 - shape_output_accuracy: 0.6484 - shape_output_loss: 0.7146
# Epoch 10: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 468ms/step - loss: 2.2507 - quality_output_accuracy: 0.3389 - quality_output_loss: 0.1138 - shape_output_accuracy: 0.6484 - shape_output_loss: 0.7140 - val_loss: 2.1035 - val_quality_output_accuracy: 0.4000 - val_quality_output_loss: 0.0870 - val_shape_output_accuracy: 0.7280 - val_shape_output_loss: 0.5658 - learning_rate: 9.0546e-04
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - loss: 2.1729 - quality_output_accuracy: 0.3576 - quality_output_loss: 0.1073 - shape_output_accuracy: 0.6940 - shape_output_loss: 0.6148
# Epoch 11: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 508ms/step - loss: 2.1727 - quality_output_accuracy: 0.3581 - quality_output_loss: 0.1072 - shape_output_accuracy: 0.6938 - shape_output_loss: 0.6151 - val_loss: 2.0916 - val_quality_output_accuracy: 0.4062 - val_quality_output_loss: 0.0922 - val_shape_output_accuracy: 0.6953 - val_shape_output_loss: 0.5852 - learning_rate: 8.8640e-04
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - loss: 2.1317 - quality_output_accuracy: 0.3629 - quality_output_loss: 0.0984 - shape_output_accuracy: 0.6836 - shape_output_loss: 0.6497
# Epoch 12: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 483ms/step - loss: 2.1314 - quality_output_accuracy: 0.3629 - quality_output_loss: 0.0984 - shape_output_accuracy: 0.6835 - shape_output_loss: 0.6494 - val_loss: 1.9762 - val_quality_output_accuracy: 0.4453 - val_quality_output_loss: 0.0893 - val_shape_output_accuracy: 0.7656 - val_shape_output_loss: 0.4315 - learning_rate: 8.6584e-04
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - loss: 2.0697 - quality_output_accuracy: 0.3968 - quality_output_loss: 0.0979 - shape_output_accuracy: 0.7119 - shape_output_loss: 0.6040
# Epoch 13: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 472ms/step - loss: 2.0697 - quality_output_accuracy: 0.3968 - quality_output_loss: 0.0979 - shape_output_accuracy: 0.7117 - shape_output_loss: 0.6044 - val_loss: 1.9644 - val_quality_output_accuracy: 0.4062 - val_quality_output_loss: 0.0844 - val_shape_output_accuracy: 0.7031 - val_shape_output_loss: 0.4950 - learning_rate: 8.4385e-04
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - loss: 2.0263 - quality_output_accuracy: 0.4218 - quality_output_loss: 0.0907 - shape_output_accuracy: 0.6962 - shape_output_loss: 0.6001
# Epoch 14: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 500ms/step - loss: 2.0261 - quality_output_accuracy: 0.4219 - quality_output_loss: 0.0907 - shape_output_accuracy: 0.6962 - shape_output_loss: 0.5999 - val_loss: 1.8968 - val_quality_output_accuracy: 0.4720 - val_quality_output_loss: 0.0820 - val_shape_output_accuracy: 0.7680 - val_shape_output_loss: 0.4295 - learning_rate: 8.2052e-04
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - loss: 1.9927 - quality_output_accuracy: 0.4160 - quality_output_loss: 0.0883 - shape_output_accuracy: 0.6875 - shape_output_loss: 0.6206
# Epoch 15: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 468ms/step - loss: 1.9928 - quality_output_accuracy: 0.4161 - quality_output_loss: 0.0883 - shape_output_accuracy: 0.6873 - shape_output_loss: 0.6210 - val_loss: 1.8886 - val_quality_output_accuracy: 0.4000 - val_quality_output_loss: 0.0788 - val_shape_output_accuracy: 0.7440 - val_shape_output_loss: 0.4923 - learning_rate: 7.9595e-04
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - loss: 1.9839 - quality_output_accuracy: 0.4074 - quality_output_loss: 0.0915 - shape_output_accuracy: 0.6910 - shape_output_loss: 0.6517
# Epoch 16: val_quality_output_accuracy did not improve from 0.47200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 509ms/step - loss: 1.9836 - quality_output_accuracy: 0.4072 - quality_output_loss: 0.0915 - shape_output_accuracy: 0.6912 - shape_output_loss: 0.6513 - val_loss: 1.8416 - val_quality_output_accuracy: 0.4297 - val_quality_output_loss: 0.0799 - val_shape_output_accuracy: 0.7500 - val_shape_output_loss: 0.4572 - learning_rate: 7.7023e-04
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 1.9187 - quality_output_accuracy: 0.3984 - quality_output_loss: 0.0871 - shape_output_accuracy: 0.7035 - shape_output_loss: 0.5988
# Epoch 17: val_quality_output_accuracy improved from 0.47200 to 0.48438, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 495ms/step - loss: 1.9185 - quality_output_accuracy: 0.3983 - quality_output_loss: 0.0871 - shape_output_accuracy: 0.7035 - shape_output_loss: 0.5986 - val_loss: 1.7472 - val_quality_output_accuracy: 0.4844 - val_quality_output_loss: 0.0783 - val_shape_output_accuracy: 0.8203 - val_shape_output_loss: 0.3365 - learning_rate: 7.4347e-04
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 1.8502 - quality_output_accuracy: 0.4213 - quality_output_loss: 0.0856 - shape_output_accuracy: 0.7292 - shape_output_loss: 0.5370
# Epoch 18: val_quality_output_accuracy did not improve from 0.48438
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 464ms/step - loss: 1.8503 - quality_output_accuracy: 0.4211 - quality_output_loss: 0.0856 - shape_output_accuracy: 0.7291 - shape_output_loss: 0.5375 - val_loss: 1.7527 - val_quality_output_accuracy: 0.4688 - val_quality_output_loss: 0.0808 - val_shape_output_accuracy: 0.7969 - val_shape_output_loss: 0.3937 - learning_rate: 7.1576e-04
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 1.8085 - quality_output_accuracy: 0.4065 - quality_output_loss: 0.0858 - shape_output_accuracy: 0.7577 - shape_output_loss: 0.4947
# Epoch 19: val_quality_output_accuracy did not improve from 0.48438
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 480ms/step - loss: 1.8084 - quality_output_accuracy: 0.4069 - quality_output_loss: 0.0858 - shape_output_accuracy: 0.7575 - shape_output_loss: 0.4949 - val_loss: 1.6988 - val_quality_output_accuracy: 0.4000 - val_quality_output_loss: 0.0722 - val_shape_output_accuracy: 0.8240 - val_shape_output_loss: 0.3823 - learning_rate: 6.8722e-04
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - loss: 1.7859 - quality_output_accuracy: 0.4540 - quality_output_loss: 0.0812 - shape_output_accuracy: 0.7330 - shape_output_loss: 0.5333
# Epoch 20: val_quality_output_accuracy improved from 0.48438 to 0.48800, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 492ms/step - loss: 1.7859 - quality_output_accuracy: 0.4538 - quality_output_loss: 0.0812 - shape_output_accuracy: 0.7331 - shape_output_loss: 0.5336 - val_loss: 1.6902 - val_quality_output_accuracy: 0.4880 - val_quality_output_loss: 0.0739 - val_shape_output_accuracy: 0.8080 - val_shape_output_loss: 0.4103 - learning_rate: 6.5796e-04
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - loss: 1.7854 - quality_output_accuracy: 0.4099 - quality_output_loss: 0.0861 - shape_output_accuracy: 0.7347 - shape_output_loss: 0.5682
# Epoch 21: val_quality_output_accuracy improved from 0.48800 to 0.54688, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 25s 511ms/step - loss: 1.7852 - quality_output_accuracy: 0.4102 - quality_output_loss: 0.0860 - shape_output_accuracy: 0.7343 - shape_output_loss: 0.5684 - val_loss: 1.6772 - val_quality_output_accuracy: 0.5469 - val_quality_output_loss: 0.0746 - val_shape_output_accuracy: 0.7969 - val_shape_output_loss: 0.4398 - learning_rate: 6.2810e-04
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - loss: 1.7362 - quality_output_accuracy: 0.4438 - quality_output_loss: 0.0816 - shape_output_accuracy: 0.7299 - shape_output_loss: 0.5660
# Epoch 22: val_quality_output_accuracy did not improve from 0.54688
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 457ms/step - loss: 1.7361 - quality_output_accuracy: 0.4436 - quality_output_loss: 0.0816 - shape_output_accuracy: 0.7300 - shape_output_loss: 0.5661 - val_loss: 1.6014 - val_quality_output_accuracy: 0.4688 - val_quality_output_loss: 0.0773 - val_shape_output_accuracy: 0.8125 - val_shape_output_loss: 0.3262 - learning_rate: 5.9775e-04
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - loss: 1.6785 - quality_output_accuracy: 0.4594 - quality_output_loss: 0.0795 - shape_output_accuracy: 0.7728 - shape_output_loss: 0.4802
# Epoch 23: val_quality_output_accuracy did not improve from 0.54688
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 481ms/step - loss: 1.6785 - quality_output_accuracy: 0.4592 - quality_output_loss: 0.0795 - shape_output_accuracy: 0.7724 - shape_output_loss: 0.4805 - val_loss: 1.5710 - val_quality_output_accuracy: 0.4844 - val_quality_output_loss: 0.0759 - val_shape_output_accuracy: 0.8281 - val_shape_output_loss: 0.3224 - learning_rate: 5.6704e-04
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 1.6580 - quality_output_accuracy: 0.4762 - quality_output_loss: 0.0789 - shape_output_accuracy: 0.7426 - shape_output_loss: 0.4992
# Epoch 24: val_quality_output_accuracy did not improve from 0.54688
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 483ms/step - loss: 1.6578 - quality_output_accuracy: 0.4759 - quality_output_loss: 0.0789 - shape_output_accuracy: 0.7429 - shape_output_loss: 0.4991 - val_loss: 1.5051 - val_quality_output_accuracy: 0.5040 - val_quality_output_loss: 0.0722 - val_shape_output_accuracy: 0.8640 - val_shape_output_loss: 0.2514 - learning_rate: 5.3608e-04
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 1.6286 - quality_output_accuracy: 0.4921 - quality_output_loss: 0.0773 - shape_output_accuracy: 0.7811 - shape_output_loss: 0.4906
# Epoch 25: val_quality_output_accuracy improved from 0.54688 to 0.55200, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 498ms/step - loss: 1.6285 - quality_output_accuracy: 0.4915 - quality_output_loss: 0.0773 - shape_output_accuracy: 0.7811 - shape_output_loss: 0.4904 - val_loss: 1.5042 - val_quality_output_accuracy: 0.5520 - val_quality_output_loss: 0.0730 - val_shape_output_accuracy: 0.8800 - val_shape_output_loss: 0.2914 - learning_rate: 5.0500e-04
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 1.6093 - quality_output_accuracy: 0.4810 - quality_output_loss: 0.0779 - shape_output_accuracy: 0.7505 - shape_output_loss: 0.4891
# Epoch 26: val_quality_output_accuracy did not improve from 0.55200
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 465ms/step - loss: 1.6088 - quality_output_accuracy: 0.4809 - quality_output_loss: 0.0779 - shape_output_accuracy: 0.7509 - shape_output_loss: 0.4885 - val_loss: 1.4637 - val_quality_output_accuracy: 0.5078 - val_quality_output_loss: 0.0744 - val_shape_output_accuracy: 0.8672 - val_shape_output_loss: 0.2508 - learning_rate: 4.7392e-04
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - loss: 1.5714 - quality_output_accuracy: 0.4580 - quality_output_loss: 0.0801 - shape_output_accuracy: 0.7718 - shape_output_loss: 0.4503
# Epoch 27: val_quality_output_accuracy improved from 0.55200 to 0.55469, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 25s 518ms/step - loss: 1.5711 - quality_output_accuracy: 0.4582 - quality_output_loss: 0.0800 - shape_output_accuracy: 0.7721 - shape_output_loss: 0.4501 - val_loss: 1.4264 - val_quality_output_accuracy: 0.5547 - val_quality_output_loss: 0.0701 - val_shape_output_accuracy: 0.8672 - val_shape_output_loss: 0.2381 - learning_rate: 4.4296e-04
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - loss: 1.5214 - quality_output_accuracy: 0.4815 - quality_output_loss: 0.0760 - shape_output_accuracy: 0.7829 - shape_output_loss: 0.4173
# Epoch 28: val_quality_output_accuracy did not improve from 0.55469
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 21s 442ms/step - loss: 1.5214 - quality_output_accuracy: 0.4814 - quality_output_loss: 0.0760 - shape_output_accuracy: 0.7828 - shape_output_loss: 0.4176 - val_loss: 1.4429 - val_quality_output_accuracy: 0.5469 - val_quality_output_loss: 0.0719 - val_shape_output_accuracy: 0.7969 - val_shape_output_loss: 0.3008 - learning_rate: 4.1225e-04
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - loss: 1.5249 - quality_output_accuracy: 0.4930 - quality_output_loss: 0.0778 - shape_output_accuracy: 0.7652 - shape_output_loss: 0.4447
# Epoch 29: val_quality_output_accuracy did not improve from 0.55469
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 483ms/step - loss: 1.5245 - quality_output_accuracy: 0.4930 - quality_output_loss: 0.0778 - shape_output_accuracy: 0.7655 - shape_output_loss: 0.4442 - val_loss: 1.4166 - val_quality_output_accuracy: 0.5200 - val_quality_output_loss: 0.0706 - val_shape_output_accuracy: 0.8480 - val_shape_output_loss: 0.2848 - learning_rate: 3.8190e-04
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - loss: 1.4923 - quality_output_accuracy: 0.4967 - quality_output_loss: 0.0758 - shape_output_accuracy: 0.7986 - shape_output_loss: 0.4278
# Epoch 30: val_quality_output_accuracy improved from 0.55469 to 0.57600, saving model to enhanced_transfer_learning_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 25s 522ms/step - loss: 1.4923 - quality_output_accuracy: 0.4967 - quality_output_loss: 0.0758 - shape_output_accuracy: 0.7985 - shape_output_loss: 0.4282 - val_loss: 1.3453 - val_quality_output_accuracy: 0.5760 - val_quality_output_loss: 0.0682 - val_shape_output_accuracy: 0.9120 - val_shape_output_loss: 0.1898 - learning_rate: 3.5204e-04
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - loss: 1.4623 - quality_output_accuracy: 0.4894 - quality_output_loss: 0.0754 - shape_output_accuracy: 0.8083 - shape_output_loss: 0.4037
# Epoch 31: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 451ms/step - loss: 1.4625 - quality_output_accuracy: 0.4893 - quality_output_loss: 0.0755 - shape_output_accuracy: 0.8081 - shape_output_loss: 0.4041 - val_loss: 1.3682 - val_quality_output_accuracy: 0.5469 - val_quality_output_loss: 0.0707 - val_shape_output_accuracy: 0.8672 - val_shape_output_loss: 0.2583 - learning_rate: 3.2278e-04
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - loss: 1.4480 - quality_output_accuracy: 0.4795 - quality_output_loss: 0.0749 - shape_output_accuracy: 0.8003 - shape_output_loss: 0.4213
# Epoch 32: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 479ms/step - loss: 1.4482 - quality_output_accuracy: 0.4797 - quality_output_loss: 0.0749 - shape_output_accuracy: 0.8000 - shape_output_loss: 0.4220 - val_loss: 1.4038 - val_quality_output_accuracy: 0.5391 - val_quality_output_loss: 0.0663 - val_shape_output_accuracy: 0.8438 - val_shape_output_loss: 0.3800 - learning_rate: 2.9424e-04
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - loss: 1.4378 - quality_output_accuracy: 0.4908 - quality_output_loss: 0.0729 - shape_output_accuracy: 0.8043 - shape_output_loss: 0.4312
# Epoch 33: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 456ms/step - loss: 1.4378 - quality_output_accuracy: 0.4910 - quality_output_loss: 0.0730 - shape_output_accuracy: 0.8041 - shape_output_loss: 0.4315 - val_loss: 1.3234 - val_quality_output_accuracy: 0.5000 - val_quality_output_loss: 0.0755 - val_shape_output_accuracy: 0.8750 - val_shape_output_loss: 0.2001 - learning_rate: 2.6653e-04
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - loss: 1.4023 - quality_output_accuracy: 0.5297 - quality_output_loss: 0.0712 - shape_output_accuracy: 0.8021 - shape_output_loss: 0.3857
# Epoch 34: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 489ms/step - loss: 1.4023 - quality_output_accuracy: 0.5293 - quality_output_loss: 0.0712 - shape_output_accuracy: 0.8022 - shape_output_loss: 0.3859 - val_loss: 1.2815 - val_quality_output_accuracy: 0.5760 - val_quality_output_loss: 0.0694 - val_shape_output_accuracy: 0.8960 - val_shape_output_loss: 0.1671 - learning_rate: 2.3977e-04
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - loss: 1.3906 - quality_output_accuracy: 0.5053 - quality_output_loss: 0.0738 - shape_output_accuracy: 0.8152 - shape_output_loss: 0.3746
# Epoch 35: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 489ms/step - loss: 1.3907 - quality_output_accuracy: 0.5054 - quality_output_loss: 0.0738 - shape_output_accuracy: 0.8154 - shape_output_loss: 0.3748 - val_loss: 1.2650 - val_quality_output_accuracy: 0.5600 - val_quality_output_loss: 0.0651 - val_shape_output_accuracy: 0.9120 - val_shape_output_loss: 0.1778 - learning_rate: 2.1405e-04
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - loss: 1.4012 - quality_output_accuracy: 0.4885 - quality_output_loss: 0.0755 - shape_output_accuracy: 0.8086 - shape_output_loss: 0.4057
# Epoch 36: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 491ms/step - loss: 1.4009 - quality_output_accuracy: 0.4887 - quality_output_loss: 0.0755 - shape_output_accuracy: 0.8087 - shape_output_loss: 0.4053 - val_loss: 1.2846 - val_quality_output_accuracy: 0.5000 - val_quality_output_loss: 0.0704 - val_shape_output_accuracy: 0.8750 - val_shape_output_loss: 0.2137 - learning_rate: 1.8948e-04
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - loss: 1.3661 - quality_output_accuracy: 0.5307 - quality_output_loss: 0.0696 - shape_output_accuracy: 0.8005 - shape_output_loss: 0.3850
# Epoch 37: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 474ms/step - loss: 1.3660 - quality_output_accuracy: 0.5306 - quality_output_loss: 0.0696 - shape_output_accuracy: 0.8008 - shape_output_loss: 0.3847 - val_loss: 1.2670 - val_quality_output_accuracy: 0.5391 - val_quality_output_loss: 0.0673 - val_shape_output_accuracy: 0.8750 - val_shape_output_loss: 0.2119 - learning_rate: 1.6615e-04
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - loss: 1.3549 - quality_output_accuracy: 0.4940 - quality_output_loss: 0.0732 - shape_output_accuracy: 0.8293 - shape_output_loss: 0.3637
# Epoch 38: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 486ms/step - loss: 1.3548 - quality_output_accuracy: 0.4941 - quality_output_loss: 0.0732 - shape_output_accuracy: 0.8293 - shape_output_loss: 0.3635 - val_loss: 1.2304 - val_quality_output_accuracy: 0.4844 - val_quality_output_loss: 0.0715 - val_shape_output_accuracy: 0.9062 - val_shape_output_loss: 0.1339 - learning_rate: 1.4416e-04
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 1.3367 - quality_output_accuracy: 0.5266 - quality_output_loss: 0.0709 - shape_output_accuracy: 0.8318 - shape_output_loss: 0.3561
# Epoch 39: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 462ms/step - loss: 1.3366 - quality_output_accuracy: 0.5265 - quality_output_loss: 0.0709 - shape_output_accuracy: 0.8319 - shape_output_loss: 0.3561 - val_loss: 1.2242 - val_quality_output_accuracy: 0.5200 - val_quality_output_loss: 0.0692 - val_shape_output_accuracy: 0.9040 - val_shape_output_loss: 0.1420 - learning_rate: 1.2360e-04
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - loss: 1.3494 - quality_output_accuracy: 0.5326 - quality_output_loss: 0.0704 - shape_output_accuracy: 0.8101 - shape_output_loss: 0.3925
# Epoch 40: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 478ms/step - loss: 1.3490 - quality_output_accuracy: 0.5329 - quality_output_loss: 0.0703 - shape_output_accuracy: 0.8104 - shape_output_loss: 0.3919 - val_loss: 1.2177 - val_quality_output_accuracy: 0.5680 - val_quality_output_loss: 0.0643 - val_shape_output_accuracy: 0.8960 - val_shape_output_loss: 0.1667 - learning_rate: 1.0454e-04
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - loss: 1.3292 - quality_output_accuracy: 0.4948 - quality_output_loss: 0.0728 - shape_output_accuracy: 0.8333 - shape_output_loss: 0.3545
# Epoch 41: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 478ms/step - loss: 1.3293 - quality_output_accuracy: 0.4950 - quality_output_loss: 0.0728 - shape_output_accuracy: 0.8332 - shape_output_loss: 0.3549 - val_loss: 1.2398 - val_quality_output_accuracy: 0.5234 - val_quality_output_loss: 0.0678 - val_shape_output_accuracy: 0.9062 - val_shape_output_loss: 0.2073 - learning_rate: 8.7058e-05
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 1.3127 - quality_output_accuracy: 0.5091 - quality_output_loss: 0.0700 - shape_output_accuracy: 0.8372 - shape_output_loss: 0.3437
# Epoch 42: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 467ms/step - loss: 1.3126 - quality_output_accuracy: 0.5091 - quality_output_loss: 0.0701 - shape_output_accuracy: 0.8374 - shape_output_loss: 0.3433 - val_loss: 1.1782 - val_quality_output_accuracy: 0.5078 - val_quality_output_loss: 0.0631 - val_shape_output_accuracy: 0.9453 - val_shape_output_loss: 0.1163 - learning_rate: 7.1228e-05
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - loss: 1.2916 - quality_output_accuracy: 0.5289 - quality_output_loss: 0.0696 - shape_output_accuracy: 0.8550 - shape_output_loss: 0.3187
# Epoch 43: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 493ms/step - loss: 1.2919 - quality_output_accuracy: 0.5289 - quality_output_loss: 0.0696 - shape_output_accuracy: 0.8546 - shape_output_loss: 0.3196 - val_loss: 1.2293 - val_quality_output_accuracy: 0.5000 - val_quality_output_loss: 0.0678 - val_shape_output_accuracy: 0.8750 - val_shape_output_loss: 0.2023 - learning_rate: 5.7111e-05
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - loss: 1.2992 - quality_output_accuracy: 0.5069 - quality_output_loss: 0.0710 - shape_output_accuracy: 0.8548 - shape_output_loss: 0.3288
# Epoch 44: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 460ms/step - loss: 1.2989 - quality_output_accuracy: 0.5076 - quality_output_loss: 0.0709 - shape_output_accuracy: 0.8549 - shape_output_loss: 0.3285 - val_loss: 1.2148 - val_quality_output_accuracy: 0.5680 - val_quality_output_loss: 0.0663 - val_shape_output_accuracy: 0.8960 - val_shape_output_loss: 0.1814 - learning_rate: 4.4761e-05
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - loss: 1.2882 - quality_output_accuracy: 0.5368 - quality_output_loss: 0.0700 - shape_output_accuracy: 0.8488 - shape_output_loss: 0.3159
# Epoch 45: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 470ms/step - loss: 1.2882 - quality_output_accuracy: 0.5366 - quality_output_loss: 0.0701 - shape_output_accuracy: 0.8488 - shape_output_loss: 0.3160 - val_loss: 1.2029 - val_quality_output_accuracy: 0.5680 - val_quality_output_loss: 0.0623 - val_shape_output_accuracy: 0.9040 - val_shape_output_loss: 0.1826 - learning_rate: 3.4227e-05
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - loss: 1.2803 - quality_output_accuracy: 0.5242 - quality_output_loss: 0.0700 - shape_output_accuracy: 0.8593 - shape_output_loss: 0.3060
# Epoch 46: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 483ms/step - loss: 1.2802 - quality_output_accuracy: 0.5244 - quality_output_loss: 0.0701 - shape_output_accuracy: 0.8593 - shape_output_loss: 0.3062 - val_loss: 1.2067 - val_quality_output_accuracy: 0.5078 - val_quality_output_loss: 0.0670 - val_shape_output_accuracy: 0.9141 - val_shape_output_loss: 0.1752 - learning_rate: 2.5551e-05
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - loss: 1.2766 - quality_output_accuracy: 0.5434 - quality_output_loss: 0.0688 - shape_output_accuracy: 0.8737 - shape_output_loss: 0.3067
# Epoch 47: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 484ms/step - loss: 1.2767 - quality_output_accuracy: 0.5434 - quality_output_loss: 0.0688 - shape_output_accuracy: 0.8736 - shape_output_loss: 0.3068 - val_loss: 1.2037 - val_quality_output_accuracy: 0.5234 - val_quality_output_loss: 0.0641 - val_shape_output_accuracy: 0.9062 - val_shape_output_loss: 0.1863 - learning_rate: 1.8768e-05
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 1.3042 - quality_output_accuracy: 0.5231 - quality_output_loss: 0.0712 - shape_output_accuracy: 0.8362 - shape_output_loss: 0.3520
# Epoch 48: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 22s 460ms/step - loss: 1.3040 - quality_output_accuracy: 0.5231 - quality_output_loss: 0.0711 - shape_output_accuracy: 0.8364 - shape_output_loss: 0.3516 - val_loss: 1.2454 - val_quality_output_accuracy: 0.5000 - val_quality_output_loss: 0.0678 - val_shape_output_accuracy: 0.8750 - val_shape_output_loss: 0.2529 - learning_rate: 1.3903e-05
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - loss: 1.2855 - quality_output_accuracy: 0.5607 - quality_output_loss: 0.0687 - shape_output_accuracy: 0.8474 - shape_output_loss: 0.3292
# Epoch 49: val_quality_output_accuracy did not improve from 0.57600
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 23s 481ms/step - loss: 1.2855 - quality_output_accuracy: 0.5608 - quality_output_loss: 0.0687 - shape_output_accuracy: 0.8473 - shape_output_loss: 0.3292 - val_loss: 1.2024 - val_quality_output_accuracy: 0.5360 - val_quality_output_loss: 0.0640 - val_shape_output_accuracy: 0.9120 - val_shape_output_loss: 0.1827 - learning_rate: 1.0977e-05
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - loss: 1.2768 - quality_output_accuracy: 0.5447 - quality_output_loss: 0.0701 - shape_output_accuracy: 0.8601 - shape_output_loss: 0.3064
# Epoch 50: val_quality_output_accuracy did not improve from 0.57600
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_55/1338650501.py in <cell line: 0>()
#       3 print("="*70 + "\n")
#       4
# ----> 5 history = model.fit(
#       6     train_generator,
#       7     steps_per_epoch=train_steps,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/optimizers/base_optimizer.py in learning_rate(self, learning_rate)
#     715                 self._learning_rate, learning_rate_schedule.LearningRateSchedule
#     716             ):
# --> 717                 raise TypeError(
#     718                     "This optimizer was created with a `LearningRateSchedule`"
#     719                     " object as its `learning_rate` constructor argument, "
#
# TypeError: This optimizer was created with a `LearningRateSchedule` object as its `learning_rate` constructor argument, hence its learning rate is not settable. If you need the learning rate to be settable, you should instantiate the optimizer with a float `learning_rate` argument.

# %% [markdown]
# ## Visualize Training History

# %%
# Enhanced visualization
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Shape accuracy
axes[0, 0].plot(history.history['shape_output_accuracy'], label='Train', linewidth=2.5, color='#2E86AB')
axes[0, 0].plot(history.history['val_shape_output_accuracy'], label='Validation', linewidth=2.5, color='#A23B72')
axes[0, 0].set_title('Shape Accuracy', fontsize=15, fontweight='bold')
axes[0, 0].set_xlabel('Epoch', fontsize=12)
axes[0, 0].set_ylabel('Accuracy', fontsize=12)
axes[0, 0].legend(fontsize=11)
axes[0, 0].grid(True, alpha=0.3, linestyle='--')

# Quality accuracy
axes[0, 1].plot(history.history['quality_output_accuracy'], label='Train', linewidth=2.5, color='#2E86AB')
axes[0, 1].plot(history.history['val_quality_output_accuracy'], label='Validation', linewidth=2.5, color='#A23B72')
axes[0, 1].set_title('Quality Accuracy', fontsize=15, fontweight='bold')
axes[0, 1].set_xlabel('Epoch', fontsize=12)
axes[0, 1].set_ylabel('Accuracy', fontsize=12)
axes[0, 1].legend(fontsize=11)
axes[0, 1].grid(True, alpha=0.3, linestyle='--')

# Combined accuracy
train_avg_acc = [(a + b) / 2 for a, b in zip(history.history['shape_output_accuracy'], 
                                              history.history['quality_output_accuracy'])]
val_avg_acc = [(a + b) / 2 for a, b in zip(history.history['val_shape_output_accuracy'], 
                                            history.history['val_quality_output_accuracy'])]
axes[0, 2].plot(train_avg_acc, label='Train', linewidth=2.5, color='#2E86AB')
axes[0, 2].plot(val_avg_acc, label='Validation', linewidth=2.5, color='#A23B72')
axes[0, 2].set_title('Average Accuracy', fontsize=15, fontweight='bold')
axes[0, 2].set_xlabel('Epoch', fontsize=12)
axes[0, 2].set_ylabel('Accuracy', fontsize=12)
axes[0, 2].legend(fontsize=11)
axes[0, 2].grid(True, alpha=0.3, linestyle='--')

# Shape loss
axes[1, 0].plot(history.history['shape_output_loss'], label='Train', linewidth=2.5, color='#F18F01')
axes[1, 0].plot(history.history['val_shape_output_loss'], label='Validation', linewidth=2.5, color='#C73E1D')
axes[1, 0].set_title('Shape Loss', fontsize=15, fontweight='bold')
axes[1, 0].set_xlabel('Epoch', fontsize=12)
axes[1, 0].set_ylabel('Loss', fontsize=12)
axes[1, 0].legend(fontsize=11)
axes[1, 0].grid(True, alpha=0.3, linestyle='--')

# Quality loss
axes[1, 1].plot(history.history['quality_output_loss'], label='Train', linewidth=2.5, color='#F18F01')
axes[1, 1].plot(history.history['val_quality_output_loss'], label='Validation', linewidth=2.5, color='#C73E1D')
axes[1, 1].set_title('Quality Loss', fontsize=15, fontweight='bold')
axes[1, 1].set_xlabel('Epoch', fontsize=12)
axes[1, 1].set_ylabel('Loss', fontsize=12)
axes[1, 1].legend(fontsize=11)
axes[1, 1].grid(True, alpha=0.3, linestyle='--')

# Total loss
axes[1, 2].plot(history.history['loss'], label='Train', linewidth=2.5, color='#F18F01')
axes[1, 2].plot(history.history['val_loss'], label='Validation', linewidth=2.5, color='#C73E1D')
axes[1, 2].set_title('Total Loss', fontsize=15, fontweight='bold')
axes[1, 2].set_xlabel('Epoch', fontsize=12)
axes[1, 2].set_ylabel('Loss', fontsize=12)
axes[1, 2].legend(fontsize=11)
axes[1, 2].grid(True, alpha=0.3, linestyle='--')

plt.tight_layout()
plt.savefig('training_history.png', dpi=300, bbox_inches='tight')
plt.show()

print("Training history visualization saved as 'training_history.png'")
# Out:
# Training history visualization saved as 'training_history.png'

# %% [markdown]
# ## Evaluate on Test Set

# %%
print("\nEvaluating on test set...")
test_results = model.evaluate(test_generator, steps=test_steps, verbose=1)

print("\n" + "="*70)
print(" " * 15 + "ENHANCED MODEL TEST RESULTS")
print("="*70)
print(f"Shape Accuracy: {test_results[3]*100:.2f}%")
print(f"Quality Accuracy: {test_results[4]*100:.2f}%")
print(f"Average Accuracy: {(test_results[3] + test_results[4])/2*100:.2f}%")
print("="*70)
# Out:
# Evaluating on test set...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - loss: 1.1692 - quality_output_accuracy: 0.6240 - quality_output_loss: 0.0616 - shape_output_accuracy: 0.9458 - shape_output_loss: 0.1346
#
# ======================================================================
#                ENHANCED MODEL TEST RESULTS
# ======================================================================
# Shape Accuracy: 60.94%
# Quality Accuracy: 94.53%
# Average Accuracy: 77.73%
# ======================================================================

# %%
# Detailed metrics with per-class analysis
y_true_shape = []
y_pred_shape = []
y_true_quality = []
y_pred_quality = []

test_generator_pred = dual_label_generator(test_df, val_test_datagen, batch_size, img_size, shuffle=False)

print("\nGenerating predictions on test set...")
for i in range(test_steps):
    batch_images, batch_labels = next(test_generator_pred)
    shape_preds, quality_preds = model.predict(batch_images, verbose=0)
    
    y_pred_shape.extend(np.argmax(shape_preds, axis=1))
    y_pred_quality.extend(np.argmax(quality_preds, axis=1))
    y_true_shape.extend(np.argmax(batch_labels['shape_output'], axis=1))
    y_true_quality.extend(np.argmax(batch_labels['quality_output'], axis=1))
    
    if (i + 1) % 10 == 0:
        print(f"  Processed {i + 1}/{test_steps} batches...")

print("\n" + "="*70)
print("SHAPE CLASSIFICATION REPORT:")
print("="*70)
print(classification_report(y_true_shape, y_pred_shape, target_names=shape_classes, digits=4))

print("\n" + "="*70)
print("QUALITY CLASSIFICATION REPORT:")
print("="*70)
print(classification_report(y_true_quality, y_pred_quality, target_names=quality_classes, digits=4))
# Out:
# Generating predictions on test set...
#
# ======================================================================
# SHAPE CLASSIFICATION REPORT:
# ======================================================================
#               precision    recall  f1-score   support
#
#       Circle     0.9744    0.9268    0.9500        41
#       Square     0.9545    0.9130    0.9333        46
#     Triangle     0.9111    1.0000    0.9535        41
#
#     accuracy                         0.9453       128
#    macro avg     0.9467    0.9466    0.9456       128
# weighted avg     0.9470    0.9453    0.9451       128
#
#
# ======================================================================
# QUALITY CLASSIFICATION REPORT:
# ======================================================================
#               precision    recall  f1-score   support
#
#    Irregular     0.5625    0.8182    0.6667        55
#       Medium     0.6774    0.4375    0.5316        48
#      Perfect     0.7059    0.4800    0.5714        25
#
#     accuracy                         0.6094       128
#    macro avg     0.6486    0.5786    0.5899       128
# weighted avg     0.6336    0.6094    0.5974       128

# %%
# Enhanced confusion matrices
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

cm_shape = confusion_matrix(y_true_shape, y_pred_shape)
disp = ConfusionMatrixDisplay(cm_shape, display_labels=shape_classes)
disp.plot(ax=axes[0], cmap='Blues', values_format='d')
axes[0].set_title('Shape Classification\n(Enhanced Transfer Learning)', fontsize=14, fontweight='bold')
axes[0].grid(False)

cm_quality = confusion_matrix(y_true_quality, y_pred_quality)
disp = ConfusionMatrixDisplay(cm_quality, display_labels=quality_classes)
disp.plot(ax=axes[1], cmap='Greens', values_format='d')
axes[1].set_title('Quality Classification\n(Enhanced Transfer Learning)', fontsize=14, fontweight='bold')
axes[1].grid(False)

plt.tight_layout()
plt.savefig('confusion_matrices.png', dpi=300, bbox_inches='tight')
plt.show()

print("Confusion matrices saved as 'confusion_matrices.png'")
# Out:
# Confusion matrices saved as 'confusion_matrices.png'

# %%
# Per-class accuracy breakdown
print("\n" + "="*70)
print("PER-CLASS ACCURACY BREAKDOWN:")
print("="*70)

from sklearn.metrics import accuracy_score

print("\nShape Classification:")
for i, shape in enumerate(shape_classes):
    mask = np.array(y_true_shape) == i
    if mask.sum() > 0:
        acc = accuracy_score(
            np.array(y_true_shape)[mask], 
            np.array(y_pred_shape)[mask]
        )
        print(f"  {shape}: {acc*100:.2f}% ({mask.sum()} samples)")

print("\nQuality Classification:")
for i, quality in enumerate(quality_classes):
    mask = np.array(y_true_quality) == i
    if mask.sum() > 0:
        acc = accuracy_score(
            np.array(y_true_quality)[mask], 
            np.array(y_pred_quality)[mask]
        )
        print(f"  {quality}: {acc*100:.2f}% ({mask.sum()} samples)")

print("="*70)
# Out:
# ======================================================================
# PER-CLASS ACCURACY BREAKDOWN:
# ======================================================================
#
# Shape Classification:
#   Circle: 92.68% (41 samples)
#   Square: 91.30% (46 samples)
#   Triangle: 100.00% (41 samples)
#
# Quality Classification:
#   Irregular: 81.82% (55 samples)
#   Medium: 43.75% (48 samples)
#   Perfect: 48.00% (25 samples)
# ======================================================================

# %% [markdown]
# ## Save Final Model

# %%
# Save model
model.save('enhanced_transfer_learning_final.keras')
print("\nFinal model saved as 'enhanced_transfer_learning_final.keras'")

# Save model summary
with open('model_summary.txt', 'w') as f:
    model.summary(print_fn=lambda x: f.write(x + '\n'))
print("Model summary saved as 'model_summary.txt'")

print("\n" + "="*70)
print("All outputs saved successfully!")
print("="*70)
# Out:
# Final model saved as 'enhanced_transfer_learning_final.keras'
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Model summary saved as 'model_summary.txt'
#
# ======================================================================
# All outputs saved successfully!
# ======================================================================

# %% [markdown]
# ## Summary of Improvements
#
# ### 1. Enhanced Synthetic Data Generation
# - **Color Variations**: Instead of just black on white, generates images with diverse foreground (8 colors) and background colors (6 colors)
# - **Better Quality Simulation**: More realistic degradation patterns for Medium and Irregular qualities
# - **Random Artifacts**: Adds scratches and imperfections to Irregular samples
#
# ### 2. Targeted Class Balancing
# - **Perfect Shapes**: Generated 150 synthetic samples for each (Circle, Square, Triangle)
# - **Medium Square**: Added 65 samples to reach ~225 total
# - **Irregular Triangle**: Added 56 samples to reach ~225 total
#
# ### 3. Architecture Improvements
# - **Larger Input**: 256×256 instead of 224×224 for better detail capture
# - **Better Regularization**: L2 regularization added to all dense layers
# - **Deeper Quality Branch**: 3 dense layers instead of 2 for harder quality classification
# - **More Parameters**: ~768-384-192/96 structure vs original 512-256-128
#
# ### 4. Optimized Hyperparameters
# - **Image Size**: 256×256 (↑ from 224)
# - **Batch Size**: 24 (↓ from 32, better for larger images)
# - **Learning Rate**: 0.0003 initial with cosine decay
# - **Epochs**: 80 (↑ from 60)
# - **Unfreezing**: From layer 120 (more aggressive fine-tuning)
#
# ### 5. Enhanced Training Strategy
# - **Stronger Focal Loss**: gamma=3.0 (↑ from 2.5) for quality
# - **Better Loss Weights**: 0.8 for shape, 1.8 for quality
# - **Cosine Decay**: Smooth learning rate schedule
# - **More Augmentation**: Increased rotation, brightness ranges
#
# ### Expected Improvements
# - Better generalization due to color diversity
# - Improved quality classification (especially for Perfect class)
# - More balanced performance across all classes
# - Less overfitting to black-on-white patterns
